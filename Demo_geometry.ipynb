# %% [markdown]
# # S-Weak order and s-Permutahedra: some demo of geometric realizations

# %%
from viewLatex import viewLatex
from spermutahedron import *

# %%
SD = SDecreasingTrees((0,2,2))

# %%
SD.projected_sweak_plot()
# Out:
# Graphics object consisting of 20 graphics primitives

# %%
SD.projected_s_tamari_plot()
# Out:
# Graphics object consisting of 16 graphics primitives

# %%
SD.projected_both_plot()
# Out:
# Graphics object consisting of 36 graphics primitives

# %%
SD = SDecreasingTrees((0,2,2,2))
SD.projected_sweak_plot()
# Out:
# Graphics3d Object

# %%
SD.projected_s_tamari_plot()
# Out:
# Graphics3d Object

# %%
SD.projected_both_plot()
# Out:
# Graphics3d Object
